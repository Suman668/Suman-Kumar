# %%
import pandas as pd
import os

# %% [markdown]
# # Merge 12 month sales data

# %%
df1 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_January_2019.csv")
df2 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_February_2019.csv")
df3 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_March_2019.csv")
df4 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_April_2019.csv")
df5 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_May_2019.csv")
df6 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_June_2019.csv")
df7 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_July_2019.csv")
df8 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_August_2019.csv")
df9 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_September_2019.csv")
df10 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_October_2019.csv")
df11 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_November_2019.csv")
df12 = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_December_2019.csv")


data = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12])
data.to_csv('All_Sales_data.csv', index = False)

# %%
df = pd.read_csv(r"C:\Users\Suman Kumar\Dropbox\PC\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\All_Sales_data.csv")
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# ...

# %% [markdown]
# # Clean the data

# %%
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
df = df.dropna(axis = 0)
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# ...

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
data = df[df['Order Date'].str[0:2] != 'Or']

# %% [markdown]
# # Which month have highest sales

# %%
data['Month'] = data['Order Date'].str[0:2]
data['Month'] = data['Month'].astype('int32')
data.head()
# Out:
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_25220/3327424754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Month'] = data['Order Date'].str[0:2]
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_25220/3327424754.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Month'] = data['Month'].astype('int32')
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# ...

# %% [markdown]
# # Add a sales Column

# %%
# for i in data.columns:
#     data[i]=pd.to_numeric(data[i],errors = 'ignore')
data['Quantity Ordered'] = pd.to_numeric(data['Quantity Ordered'])
data['Price Each'] = pd.to_numeric(data['Price Each'])
# Out:
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_25220/4076163072.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Quantity Ordered'] = pd.to_numeric(data['Quantity Ordered'])
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_25220/4076163072.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Price Each'] = pd.to_numeric(data['Price Each'])

# %%
data.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int32
# dtype: object

# %%
data['Sales']= data['Quantity Ordered']*data['Price Each']
data
# Out:
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_25220/2563763379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sales']= data['Quantity Ordered']*data['Price Each']
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# ...

# %%
Monthly_sales = data.groupby('Month').sum()
Monthly_sales
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# 12                28114  4588415.41  4613443.34

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))

Months = range(1,13)

plt.bar(Months,Monthly_sales['Sales'])
plt.xticks(Months , size = 12)
plt.yticks(Monthly_sales['Sales'],size = 12)
plt.xlabel('Months',size = 16)
plt.ylabel('Sales in $',size = 16)
# Out:
# Text(0, 0.5, 'Sales in $')

# %% [markdown]
# # Which City has highest Sales

# %%
data.head(4)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
#
#        Order Date                       Purchase Address  Month   Sales
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1  149.99

# %%
# Add a city column

def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2].split(' ')[1]

data['City'] = data['Purchase Address'].apply(lambda x : get_city(x)+' ('+get_state(x)+')')
data.head(4)
# Out:
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_25220/1004161307.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['City'] = data['Purchase Address'].apply(lambda x : get_city(x)+' ('+get_state(x)+')')
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
#
#        Order Date                       Purchase Address  Month   Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1  700.00
# ...

# %%
City_wise_sales = data.groupby('City').sum()
City_wise_sales
# Out:
#                      Quantity Ordered  Price Each   Month       Sales
# City
#  Atlanta (GA)                   16602  2779908.20  104794  2795498.58
#  Austin (TX)                    11153  1809873.61   69829  1819581.75
#  Boston (MA)                    22528  3637409.77  141112  3661642.01
#  Dallas (TX)                    16730  2752627.82  104620  2767975.40
#  Los Angeles (CA)               33289  5421435.23  208325  5452570.80
#  New York City (NY)             27932  4635370.83  175741  4664317.43
#  Portland (ME)                   2750   447189.25   17144   449758.27
#  Portland (OR)                  11303  1860558.22   70621  1870732.34
#  San Francisco (CA)             50239  8211461.74  315520  8262203.91
#  Seattle (WA)                   16553  2733296.01  104941  2747755.48

# %%
plt.figure(figsize=(16,8))

cities = [city for city , df in data.groupby('City')]

plt.bar(cities,City_wise_sales['Sales'])
plt.xticks(cities,rotation = 'vertical',size = 12)
plt.yticks(City_wise_sales['Sales'], size = 12)
plt.xlabel('City Names', size = 16)
plt.ylabel('Sales in $',size = 16)
# Out:
# Text(0, 0.5, 'Sales in $')

# %% [markdown]
# # What time should we display advertisements to maximise the likelhood of customer's buying product

# %%
data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address  Month   Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301      1   11.99
#
#                   City
# 0          Boston (MA)
# 1        Portland (OR)
# 2   San Francisco (CA)
# 3     Los Angeles (CA)
# ...

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
# Out:
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_25220/3021409918.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Order Date'] = pd.to_datetime(data['Order Date'])

# %%
data.head(4)
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
#
#            Order Date                       Purchase Address  Month   Sales  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215      1  700.00
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035      1   14.95
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016      1   23.98
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001      1  149.99
#
#                   City
# 0          Boston (MA)
# 1        Portland (OR)
# 2   San Francisco (CA)
# 3     Los Angeles (CA)

# %%
data['Hour'] = data['Order Date'].dt.hour
data['Minute'] = data['Order Date'].dt.minute
data.head(4)
# Out:
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_25220/3877360874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Hour'] = data['Order Date'].dt.hour
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_25220/3877360874.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Minute'] = data['Order Date'].dt.minute
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# ...

# %%
hours = [hour for hour , df in data.groupby('Hour')]
plt.figure(figsize = (12,8))
plt.plot(hours,data.groupby('Hour').count())
plt.xticks(hours)
plt.xlabel('Hour', size = 16)
plt.ylabel('Number of Orders', size = 16)
plt.grid()
plt.show()

# %% [markdown]
# # What are the most often products sold together

# %%
df1 = data[data['Order ID'].duplicated(keep = False)]
df1
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 41       141275      USB-C Charging Cable                 1       11.95
# 42       141275          Wired Headphones                 1       11.99
# 57       141290  Apple Airpods Headphones                 1      150.00
# 58       141290     AA Batteries (4-pack)                 3        3.84
# 133      141365           Vareebadd Phone                 1      400.00
# ...         ...                       ...               ...         ...
# 186761   319584          Wired Headphones                 1       11.99
# 186773   319596                    iPhone                 1      700.00
# 186774   319596  Lightning Charging Cable                 1       14.95
# 186809   319631    34in Ultrawide Monitor                 1      379.99
# 186810   319631  Lightning Charging Cable                 1       14.95
#
#                 Order Date                        Purchase Address  Month  \
# ...

# %%
df1['Group'] = df1.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df1.head(4)
# Out:
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_25220/720416174.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Group'] = df1.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 41   141275      USB-C Charging Cable                 1       11.95
# 42   141275          Wired Headphones                 1       11.99
# 57   141290  Apple Airpods Headphones                 1      150.00
# 58   141290     AA Batteries (4-pack)                 3        3.84
#
#             Order Date                 Purchase Address  Month   Sales  \
# 41 2019-01-07 16:06:00  610 Walnut St, Austin, TX 73301      1   11.95
# ...

# %%
df1 = df1[['Order ID','Group']].drop_duplicates()
df1
# Out:
#        Order ID                                            Group
# 41       141275            USB-C Charging Cable,Wired Headphones
# 57       141290   Apple Airpods Headphones,AA Batteries (4-pack)
# 133      141365                 Vareebadd Phone,Wired Headphones
# 153      141384                Google Phone,USB-C Charging Cable
# 220      141450          Google Phone,Bose SoundSport Headphones
# ...         ...                                              ...
# 186710   319536              Macbook Pro Laptop,Wired Headphones
# 186731   319556                    Google Phone,Wired Headphones
# 186760   319584                          iPhone,Wired Headphones
# 186773   319596                  iPhone,Lightning Charging Cable
# 186809   319631  34in Ultrawide Monitor,Lightning Charging Cable
#
# [7136 rows x 2 columns]

# %% [markdown]
# # Which product sold the most ? and why it sold the most ?

# %%
data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address  Month   Sales  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215      1  700.00
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035      1   14.95
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016      1   23.98
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001      1  149.99
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301      1   11.99
#
#                   City  Hour  Minute
# 0          Boston (MA)    21      25
# ...

# %%
Product_group = data.groupby('Product',as_index = False).sum()
Product_group
# Out:
#                        Product  Quantity Ordered  Price Each   Month  \
# 0                 20in Monitor              4129   451068.99   29336
# 1       27in 4K Gaming Monitor              6244  2429637.70   44440
# 2             27in FHD Monitor              7550  1125974.93   52558
# 3       34in Ultrawide Monitor              6199  2348718.19   43304
# 4        AA Batteries (4-pack)             27635    79015.68  145558
# 5       AAA Batteries (4-pack)             31017    61716.59  146370
# 6     Apple Airpods Headphones             15661  2332350.00  109477
# 7   Bose SoundSport Headphones             13457  1332366.75   94113
# 8                Flatscreen TV              4819  1440000.00   34224
# 9                 Google Phone              5532  3315000.00   38305
# 10                    LG Dryer               646   387600.00    4383
# 11          LG Washing Machine               666   399600.00    4523
# 12    Lightning Charging Cable             23217   323787.10  153092
# ...

# %%
plt.figure(figsize = (14,8))
# products = [product for product , df in Product_group]

plt.bar(Product_group['Product'],Product_group['Quantity Ordered'],color = 'blue')
plt.xticks(products,rotation = 'vertical',size = 12)
plt.yticks(Quantity_ordered , size = 12)
plt.xlabel('Product Name', size = 16)
plt.ylabel('Quantity_ordered',size = 16)
plt.show()

# %%
Avg_price = data.groupby('Product', as_index = False)['Price Each'].mean()
Avg_price
# Out:
#                        Product  Price Each
# 0                 20in Monitor      109.99
# 1       27in 4K Gaming Monitor      389.99
# 2             27in FHD Monitor      149.99
# 3       34in Ultrawide Monitor      379.99
# 4        AA Batteries (4-pack)        3.84
# 5       AAA Batteries (4-pack)        2.99
# 6     Apple Airpods Headphones      150.00
# 7   Bose SoundSport Headphones       99.99
# 8                Flatscreen TV      300.00
# 9                 Google Phone      600.00
# 10                    LG Dryer      600.00
# 11          LG Washing Machine      600.00
# 12    Lightning Charging Cable       14.95
# 13          Macbook Pro Laptop     1700.00
# 14             ThinkPad Laptop      999.99
# 15        USB-C Charging Cable       11.95
# 16             Vareebadd Phone      400.00
# 17            Wired Headphones       11.99
# 18                      iPhone      700.00

# %%
plt.figure(figsize = (12,8))
fig , ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.bar(Product_group['Product'],Product_group['Quantity Ordered'])
ax2.plot(Product_group['Product'],Avg_price['Price Each'], 'red')
ax1.set_xlabel('Product Name', size = 12)
ax1.set_ylabel('Quantity Ordered', size = 12)
ax2.set_ylabel('Avg_price', color = 'red',size = 12)
ax1.set_xticklabels(Product_group['Product'] ,rotation = 'vertical')
plt.show()
# Out:
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_25220/3414951445.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(Product_group['Product'] ,rotation = 'vertical')
